# %% [markdown]
# # COGS 18 Project
# Arlan Ng
#
# PID: A14934841

# %% [markdown]
# ## Project Description
# Having recently been tracking how much I spend per month, I wanted to base my project around this idea, as I saw this idea as a practical, but also intersting project. This project tracks the expenses of a person, taking the date, category, description, amount, and form of payment of each expense. We are able to calculate the total amount and the most expensive expense of the expense list. There are also functions to sort the expense list by any key within the expenses, which allows for organization and easier understanding how what areas you may be spending more in. Finally, to perform a complete analysis of one's expenses, a pie chart based on date, category, or form of payment is displayed to understand the expense list visually.

# %%
from expense import Expense

# %%
expense_list = Expense()

# %% [markdown]
# ### Create the Expense List

# %%
expense_list.add('12/01/2020', 'Groceries', 'Vons', 100, 'Credit Card')
expense_list.add('12/02/2020', 'Rent', 'Rent', 600, 'Check')
expense_list.add('12/02/2020', 'Groceries', 'Ralphs', 25, 'Cash')
expense_list.add('12/02/2020', 'Utilities', 'Water', 30, 'Venmo')
expense_list.add('12/02/2020', 'Food', 'In n Out', 10.50, 'Cash')
expense_list.add('12/04/2020', 'Groceries', 'Ralphs', 25, 'Credit Card')
expense_list.add('12/05/2020', 'Utilities', 'Gas', 15, 'Venmo')
expense_list.add('12/05/2020', 'Utilities', 'Water', 30, 'Venmo')
expense_list.print_expense()
# Out:
# {'Date': '12/01/2020', 'Category': 'Groceries', 'Description': 'Vons', 'Amount': 100, 'Form': 'Credit Card'}
# {'Date': '12/02/2020', 'Category': 'Rent', 'Description': 'Rent', 'Amount': 600, 'Form': 'Check'}
# {'Date': '12/02/2020', 'Category': 'Groceries', 'Description': 'Ralphs', 'Amount': 25, 'Form': 'Cash'}
# {'Date': '12/02/2020', 'Category': 'Utilities', 'Description': 'Water', 'Amount': 30, 'Form': 'Venmo'}
# {'Date': '12/02/2020', 'Category': 'Food', 'Description': 'In n Out', 'Amount': 10.5, 'Form': 'Cash'}
# {'Date': '12/04/2020', 'Category': 'Groceries', 'Description': 'Ralphs', 'Amount': 25, 'Form': 'Credit Card'}
# {'Date': '12/05/2020', 'Category': 'Utilities', 'Description': 'Gas', 'Amount': 15, 'Form': 'Venmo'}
# {'Date': '12/05/2020', 'Category': 'Utilities', 'Description': 'Water', 'Amount': 30, 'Form': 'Venmo'}

# %% [markdown]
# ### The Most Expensive Expense Within the List

# %%
max = expense_list.highest()
print(max)
# Out:
# 600

# %% [markdown]
# ### The Total Cost of the Expense List

# %%
total = expense_list.total()
print(total)
# Out:
# 835.5

# %% [markdown]
# ### All the Expenses Made on December 2, 2020

# %%
expense_list.spent_on('12/02/2020')
# Out:
# {'Date': '12/02/2020', 'Category': 'Rent', 'Description': 'Rent', 'Amount': 600, 'Form': 'Check'}
# {'Date': '12/02/2020', 'Category': 'Groceries', 'Description': 'Ralphs', 'Amount': 25, 'Form': 'Cash'}
# {'Date': '12/02/2020', 'Category': 'Utilities', 'Description': 'Water', 'Amount': 30, 'Form': 'Venmo'}
# {'Date': '12/02/2020', 'Category': 'Food', 'Description': 'In n Out', 'Amount': 10.5, 'Form': 'Cash'}

# %% [markdown]
# ### The Expense List Sorted by Date

# %%
expense_list.sort_by('Date')
# Out:
# {'Date': '12/01/2020', 'Category': 'Groceries', 'Description': 'Vons', 'Amount': 100, 'Form': 'Credit Card'}
# {'Date': '12/02/2020', 'Category': 'Rent', 'Description': 'Rent', 'Amount': 600, 'Form': 'Check'}
# {'Date': '12/02/2020', 'Category': 'Groceries', 'Description': 'Ralphs', 'Amount': 25, 'Form': 'Cash'}
# {'Date': '12/02/2020', 'Category': 'Utilities', 'Description': 'Water', 'Amount': 30, 'Form': 'Venmo'}
# {'Date': '12/02/2020', 'Category': 'Food', 'Description': 'In n Out', 'Amount': 10.5, 'Form': 'Cash'}
# {'Date': '12/04/2020', 'Category': 'Groceries', 'Description': 'Ralphs', 'Amount': 25, 'Form': 'Credit Card'}
# {'Date': '12/05/2020', 'Category': 'Utilities', 'Description': 'Gas', 'Amount': 15, 'Form': 'Venmo'}
# {'Date': '12/05/2020', 'Category': 'Utilities', 'Description': 'Water', 'Amount': 30, 'Form': 'Venmo'}

# %%
expense_list.plot_by('Date')

# %% [markdown]
# ### The Expense List Sorted By Category

# %%
expense_list.sort_by('Category')
# Out:
# {'Date': '12/02/2020', 'Category': 'Food', 'Description': 'In n Out', 'Amount': 10.5, 'Form': 'Cash'}
# {'Date': '12/01/2020', 'Category': 'Groceries', 'Description': 'Vons', 'Amount': 100, 'Form': 'Credit Card'}
# {'Date': '12/02/2020', 'Category': 'Groceries', 'Description': 'Ralphs', 'Amount': 25, 'Form': 'Cash'}
# {'Date': '12/04/2020', 'Category': 'Groceries', 'Description': 'Ralphs', 'Amount': 25, 'Form': 'Credit Card'}
# {'Date': '12/02/2020', 'Category': 'Rent', 'Description': 'Rent', 'Amount': 600, 'Form': 'Check'}
# {'Date': '12/02/2020', 'Category': 'Utilities', 'Description': 'Water', 'Amount': 30, 'Form': 'Venmo'}
# {'Date': '12/05/2020', 'Category': 'Utilities', 'Description': 'Gas', 'Amount': 15, 'Form': 'Venmo'}
# {'Date': '12/05/2020', 'Category': 'Utilities', 'Description': 'Water', 'Amount': 30, 'Form': 'Venmo'}

# %%
expense_list.plot_by('Category')

# %% [markdown]
# ### The Expense List Sorted By Form of Payment

# %%
expense_list.sort_by('Form')
# Out:
# {'Date': '12/02/2020', 'Category': 'Groceries', 'Description': 'Ralphs', 'Amount': 25, 'Form': 'Cash'}
# {'Date': '12/02/2020', 'Category': 'Food', 'Description': 'In n Out', 'Amount': 10.5, 'Form': 'Cash'}
# {'Date': '12/02/2020', 'Category': 'Rent', 'Description': 'Rent', 'Amount': 600, 'Form': 'Check'}
# {'Date': '12/01/2020', 'Category': 'Groceries', 'Description': 'Vons', 'Amount': 100, 'Form': 'Credit Card'}
# {'Date': '12/04/2020', 'Category': 'Groceries', 'Description': 'Ralphs', 'Amount': 25, 'Form': 'Credit Card'}
# {'Date': '12/02/2020', 'Category': 'Utilities', 'Description': 'Water', 'Amount': 30, 'Form': 'Venmo'}
# {'Date': '12/05/2020', 'Category': 'Utilities', 'Description': 'Gas', 'Amount': 15, 'Form': 'Venmo'}
# {'Date': '12/05/2020', 'Category': 'Utilities', 'Description': 'Water', 'Amount': 30, 'Form': 'Venmo'}

# %%
expense_list.plot_by('Form')

# %%
# !pytest test.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.7.6, pytest-6.1.2, py-1.9.0, pluggy-0.13.1
# rootdir: /home/a3ng/COGS 18 Project
# collected 4 items
#
# test.py ....                                                             [100%]
#
# ============================== 4 passed in 1.15s ===============================

# %% [markdown]
# ### Extra Credit
#
# Background
# - My knowledge of Python is based on the lessons and practice that is offered by CodeAcademy. That consists of knowing the basics of python, most of which was also taught in this class.
#
# For this project, I have learned several new topics that helped my code run better and more efficiently.
# - I learned list and dictionary comprehensions to minimize the length of my code and help it run faster. This way, there are no new temporary lists or dictionaries created, which consumes more memory.
# - I learned how to use matplotlib to create a pie chart, which I felt would be helpful to this project. Having to fiqure out of to combine similar keys and updating their items was the more difficult part of this function, in order for the pie chart to have more accurate percentages of each category.
# - I have exceeded the required number of functions of 3 functions.
